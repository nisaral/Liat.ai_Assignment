# %% [markdown]
# <a href="https://colab.research.google.com/github/nisaral/Liat.ai_Assignment/blob/main/liat_ai_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.159-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.159-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 34.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.159 ultralytics-thop-2.0.14

# %%
import cv2
import torch
import numpy as np
from ultralytics import YOLO
import pickle
from scipy.optimize import linear_sum_assignment
from sklearn.metrics.pairwise import cosine_similarity
import os
import json
from collections import defaultdict, deque
import matplotlib.pyplot as plt

class PlayerFeatureExtractor:
    """Extract features for player re-identification"""

    def __init__(self):
        self.color_bins = 32

    def extract_color_histogram(self, image, mask=None):
        """Extract color histogram features"""
        if image.size == 0:
            return np.zeros(self.color_bins * self.color_bins * self.color_bins)

        if mask is not None:
            image = cv2.bitwise_and(image, image, mask=mask)

        # Convert to HSV for better color representation
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

        # Calculate histogram
        hist = cv2.calcHist([hsv], [0, 1, 2], mask,
                           [self.color_bins, self.color_bins, self.color_bins],
                           [0, 180, 0, 256, 0, 256])

        # Normalize histogram
        hist = cv2.normalize(hist, hist).flatten()
        return hist

    def extract_position_features(self, bbox, frame_shape):
        """Extract normalized position features"""
        x1, y1, x2, y2 = bbox[:4]  # Ensure only first four values are used
        h, w = frame_shape[:2]

        # Normalize coordinates
        center_x = ((x1 + x2) / 2) / w
        center_y = ((y1 + y2) / 2) / h
        bbox_w = (x2 - x1) / w
        bbox_h = (y2 - y1) / h

        return np.array([center_x, center_y, bbox_w, bbox_h])

    def extract_motion_features(self, current_pos, prev_pos, time_diff=1):
        """Extract motion features"""
        if prev_pos is None:
            return np.array([0, 0, 0])

        vel_x = (current_pos[0] - prev_pos[0]) / time_diff
        vel_y = (current_pos[1] - prev_pos[1]) / time_diff
        speed = np.sqrt(vel_x**2 + vel_y**2)

        return np.array([vel_x, vel_y, speed])

class CrossCameraPlayerMapper:
    """Main class for cross-camera player mapping"""

    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model.to(self.device)
        self.feature_extractor = PlayerFeatureExtractor()
        self.broadcast_players = defaultdict(list)
        self.tacticam_players = defaultdict(list)
        self.player_mappings = {}

    def detect_players(self, frame):
        """Detect players in frame using YOLO"""
        results = self.model(frame)
        players = []

        for result in results:
            boxes = result.boxes
            if boxes is not None:
                for box in boxes:
                    # Include players, goalkeepers, and referees (adjust class IDs as needed)
                    if int(box.cls) in [0, 1, 2]:  # 0: player, 1: goalkeeper, 2: referee
                        xyxy = box.xyxy[0].cpu().numpy()
                        conf = box.conf[0].cpu().numpy()
                        if conf > 0.5:  # Confidence threshold
                            players.append([int(xyxy[0]), int(xyxy[1]), int(xyxy[2]), int(xyxy[3]), conf])

        return players

    def extract_player_features(self, frame, bbox):
        """Extract comprehensive features for a player"""
        x1, y1, x2, y2 = bbox[:4]
        if x1 >= x2 or y1 >= y2 or x1 < 0 or y1 < 0 or x2 > frame.shape[1] or y2 > frame.shape[0]:
            return None

        # Crop player region
        player_crop = frame[y1:y2, x1:x2]
        if player_crop.size == 0:
            return None

        # Create mask for player region
        mask = np.ones((y2-y1, x2-x1), dtype=np.uint8) * 255

        # Extract features
        color_hist = self.feature_extractor.extract_color_histogram(player_crop, mask)
        pos_features = self.feature_extractor.extract_position_features(bbox, frame.shape)

        # Combine features
        features = np.concatenate([color_hist, pos_features])
        return features

    def process_video(self, video_path, camera_type='broadcast'):
        """Process video and extract player features"""
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            raise ValueError(f"Could not open video: {video_path}")

        frame_count = 0
        player_tracks = defaultdict(list)
        print(f"Processing {camera_type} video...")

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Detect players
            players = self.detect_players(frame)

            # Extract features for each player
            for i, player_bbox in enumerate(players):
                features = self.extract_player_features(frame, player_bbox)
                if features is not None:
                    player_data = {
                        'frame': frame_count,
                        'bbox': player_bbox,
                        'features': features,
                        'timestamp': frame_count / 30.0  # Assuming 30 FPS
                    }

                    # Simple tracking based on proximity
                    assigned = False
                    for track_id in player_tracks:
                        if len(player_tracks[track_id]) > 0:
                            last_pos = player_tracks[track_id][-1]['bbox']
                            current_pos = player_bbox

                            dist = np.sqrt((current_pos[0] - last_pos[0])**2 +
                                         (current_pos[1] - last_pos[1])**2)

                            if dist < 100:  # Proximity threshold
                                player_tracks[track_id].append(player_data)
                                assigned = True
                                break

                    if not assigned:
                        new_id = len(player_tracks)
                        player_tracks[new_id].append(player_data)

            frame_count += 1
            if frame_count % 100 == 0:
                print(f"Processed {frame_count} frames...")

        cap.release()

        if camera_type == 'broadcast':
            self.broadcast_players = player_tracks
        else:
            self.tacticam_players = player_tracks

        return player_tracks

    def calculate_similarity(self, features1, features2):
        """Calculate similarity between two feature vectors"""
        color_features1 = features1[:-4]
        color_features2 = features2[:-4]
        pos_features1 = features1[-4:]
        pos_features2 = features2[-4:]

        # Calculate color similarity
        color_sim = cosine_similarity([color_features1], [color_features2])[0][0]

        # Calculate position similarity
        pos_dist = np.linalg.norm(pos_features1[:2] - pos_features2[:2])
        pos_sim = 1 / (1 + pos_dist)

        # Calculate size similarity
        size_sim = 1 - abs(pos_features1[2] * pos_features1[3] - pos_features2[2] * pos_features2[3])

        # Weighted combination
        total_sim = 0.6 * color_sim + 0.3 * pos_sim + 0.1 * size_sim
        return total_sim

    def map_players_across_cameras(self):
        """Map players between broadcast and tacticam videos"""
        print("Mapping players across cameras...")

        broadcast_features = []
        tacticam_features = []
        broadcast_ids = []
        tacticam_ids = []

        # Aggregate features for each player
        for player_id, tracks in self.broadcast_players.items():
            if len(tracks) > 5:
                features_list = [track['features'] for track in tracks]
                median_features = np.median(features_list, axis=0)
                broadcast_features.append(median_features)
                broadcast_ids.append(player_id)

        for player_id, tracks in self.tacticam_players.items():
            if len(tracks) > 5:
                features_list = [track['features'] for track in tracks]
                median_features = np.median(features_list, axis=0)
                tacticam_features.append(median_features)
                tacticam_ids.append(player_id)

        if not broadcast_features or not tacticam_features:
            print("Warning: Insufficient player tracks for mapping.")
            return {}

        # Calculate similarity matrix
        similarity_matrix = np.zeros((len(broadcast_features), len(tacticam_features)))
        for i, b_feat in enumerate(broadcast_features):
            for j, t_feat in enumerate(tacticam_features):
                similarity_matrix[i, j] = self.calculate_similarity(b_feat, t_feat)

        # Use Hungarian algorithm
        row_ind, col_ind = linear_sum_assignment(-similarity_matrix)

        # Create mappings
        mappings = {}
        for i, j in zip(row_ind, col_ind):
            if similarity_matrix[i, j] > 0.5:
                mappings[broadcast_ids[i]] = tacticam_ids[j]

        self.player_mappings = mappings
        return mappings

    def visualize_mappings(self, broadcast_path, tacticam_path, output_path):
        """Create visualization of player mappings"""
        cap_b = cv2.VideoCapture(broadcast_path)
        cap_t = cv2.VideoCapture(tacticam_path)

        ret_b, frame_b = cap_b.read()
        ret_t, frame_t = cap_t.read()

        if ret_b and ret_t:
            for b_id, t_id in self.player_mappings.items():
                if b_id in self.broadcast_players and t_id in self.tacticam_players:
                    b_track = self.broadcast_players[b_id][0]
                    t_track = self.tacticam_players[t_id][0]

                    b_bbox = b_track['bbox']
                    cv2.rectangle(frame_b, (b_bbox[0], b_bbox[1]), (b_bbox[2], b_bbox[3]), (0, 255, 0), 2)
                    cv2.putText(frame_b, f'P{b_id}', (b_bbox[0], b_bbox[1]-10),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

                    t_bbox = t_track['bbox']
                    cv2.rectangle(frame_t, (t_bbox[0], t_bbox[1]), (t_bbox[2], t_bbox[3]), (0, 255, 0), 2)
                    cv2.putText(frame_t, f'P{b_id}', (t_bbox[0], t_bbox[1]-10),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            combined = np.hstack([frame_b, frame_t])
            cv2.imwrite(output_path, combined)

        cap_b.release()
        cap_t.release()

    def save_results(self, output_dir):
        """Save mapping results"""
        os.makedirs(output_dir, exist_ok=True)

        with open(os.path.join(output_dir, 'player_mappings.json'), 'w') as f:
            json.dump(self.player_mappings, f, indent=2)

        with open(os.path.join(output_dir, 'broadcast_tracks.pkl'), 'wb') as f:
            pickle.dump(dict(self.broadcast_players), f)

        with open(os.path.join(output_dir, 'tacticam_tracks.pkl'), 'wb') as f:
            pickle.dump(dict(self.tacticam_players), f)

        print(f"Results saved to {output_dir}")

def main():
    # Configuration
    MODEL_PATH = "best.pt"  # Relative path
    BROADCAST_VIDEO = "broadcast.mp4"
    TACTICAM_VIDEO = "tacticam.mp4"
    OUTPUT_DIR = "results"

    # Initialize mapper
    mapper = CrossCameraPlayerMapper(MODEL_PATH)

    # Process videos
    print("Processing broadcast video...")
    mapper.process_video(BROADCAST_VIDEO, 'broadcast')

    print("Processing tacticam video...")
    mapper.process_video(TACTICAM_VIDEO, 'tacticam')

    # Map players
    mappings = mapper.map_players_across_cameras()

    print(f"Found {len(mappings)} player mappings:")
    for b_id, t_id in mappings.items():
        print(f"Broadcast Player {b_id} -> Tacticam Player {t_id}")

    # Save results
    mapper.save_results(OUTPUT_DIR)

    # Create visualization
    mapper.visualize_mappings(BROADCAST_VIDEO, TACTICAM_VIDEO,
                             os.path.join(OUTPUT_DIR, 'mapping_visualization.jpg'))

    print("Cross-camera player mapping completed!")

if __name__ == "__main__":
    main()
# Out:
# Processing broadcast video...
# Processing broadcast video...
#
# 0: 384x640 3 players, 2297.7ms
# Speed: 5.3ms preprocess, 2297.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 2299.7ms
# Speed: 4.2ms preprocess, 2299.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 3328.7ms
# Speed: 4.3ms preprocess, 3328.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 2332.3ms
# Speed: 4.9ms preprocess, 2332.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 2303.5ms
# Speed: 4.1ms preprocess, 2303.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2289.5ms
# Speed: 3.2ms preprocess, 2289.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 2286.1ms
# Speed: 3.9ms preprocess, 2286.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 14 players, 1 referee, 3154.2ms
# Speed: 3.1ms preprocess, 3154.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 2419.5ms
# Speed: 3.6ms preprocess, 2419.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 2275.0ms
# Speed: 3.2ms preprocess, 2275.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2291.8ms
# Speed: 3.0ms preprocess, 2291.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 2293.5ms
# Speed: 3.5ms preprocess, 2293.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 3103.3ms
# Speed: 3.7ms preprocess, 3103.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2495.6ms
# Speed: 4.3ms preprocess, 2495.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 3 referees, 2297.6ms
# Speed: 3.8ms preprocess, 2297.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2313.0ms
# Speed: 3.6ms preprocess, 2313.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2316.1ms
# Speed: 3.5ms preprocess, 2316.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 3062.4ms
# Speed: 3.9ms preprocess, 3062.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 2 referees, 2470.1ms
# Speed: 8.7ms preprocess, 2470.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2306.5ms
# Speed: 3.4ms preprocess, 2306.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 2288.3ms
# Speed: 3.2ms preprocess, 2288.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2297.1ms
# Speed: 4.1ms preprocess, 2297.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 3008.3ms
# Speed: 4.0ms preprocess, 3008.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2564.1ms
# Speed: 3.9ms preprocess, 2564.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2320.6ms
# Speed: 4.9ms preprocess, 2320.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2335.2ms
# Speed: 4.9ms preprocess, 2335.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 2326.8ms
# Speed: 5.3ms preprocess, 2326.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 3073.5ms
# Speed: 5.8ms preprocess, 3073.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 2558.3ms
# Speed: 5.9ms preprocess, 2558.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 2318.6ms
# Speed: 4.9ms preprocess, 2318.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 2306.8ms
# Speed: 6.4ms preprocess, 2306.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3 referees, 2350.1ms
# Speed: 4.3ms preprocess, 2350.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 3136.3ms
# Speed: 4.9ms preprocess, 3136.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 2472.1ms
# Speed: 5.7ms preprocess, 2472.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 2337.0ms
# Speed: 5.3ms preprocess, 2337.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 2766.5ms
# Speed: 3.7ms preprocess, 2766.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 2329.4ms
# Speed: 3.6ms preprocess, 2329.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 3316.1ms
# Speed: 5.5ms preprocess, 3316.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2334.8ms
# Speed: 4.2ms preprocess, 2334.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2317.4ms
# Speed: 3.8ms preprocess, 2317.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2319.4ms
# Speed: 5.5ms preprocess, 2319.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2327.5ms
# Speed: 3.7ms preprocess, 2327.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 3289.7ms
# Speed: 4.2ms preprocess, 3289.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 2330.1ms
# Speed: 3.8ms preprocess, 2330.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1 referee, 2325.7ms
# Speed: 4.6ms preprocess, 2325.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2342.9ms
# Speed: 3.7ms preprocess, 2342.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 2312.9ms
# Speed: 5.6ms preprocess, 2312.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1 referee, 3256.2ms
# Speed: 4.4ms preprocess, 3256.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 2336.3ms
# Speed: 3.7ms preprocess, 2336.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2320.9ms
# Speed: 3.5ms preprocess, 2320.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2312.7ms
# Speed: 3.0ms preprocess, 2312.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 12 players, 2380.0ms
# Speed: 3.8ms preprocess, 2380.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 3246.0ms
# Speed: 5.1ms preprocess, 3246.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2332.2ms
# Speed: 3.9ms preprocess, 2332.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 2306.3ms
# Speed: 3.7ms preprocess, 2306.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2379.7ms
# Speed: 5.6ms preprocess, 2379.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 2452.0ms
# Speed: 3.4ms preprocess, 2452.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 3092.8ms
# Speed: 4.3ms preprocess, 3092.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 2297.5ms
# Speed: 4.2ms preprocess, 2297.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3 referees, 2318.4ms
# Speed: 5.9ms preprocess, 2318.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 2359.8ms
# Speed: 3.6ms preprocess, 2359.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3 referees, 2549.8ms
# Speed: 3.3ms preprocess, 2549.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 3026.8ms
# Speed: 4.3ms preprocess, 3026.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 2308.6ms
# Speed: 3.7ms preprocess, 2308.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2323.7ms
# Speed: 3.9ms preprocess, 2323.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 2320.9ms
# Speed: 3.5ms preprocess, 2320.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 2571.6ms
# Speed: 4.4ms preprocess, 2571.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 3014.2ms
# Speed: 4.1ms preprocess, 3014.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 2357.3ms
# Speed: 4.1ms preprocess, 2357.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1 referee, 2330.0ms
# Speed: 4.4ms preprocess, 2330.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 2305.1ms
# Speed: 4.3ms preprocess, 2305.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2701.2ms
# Speed: 5.2ms preprocess, 2701.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 2891.8ms
# Speed: 6.1ms preprocess, 2891.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2338.9ms
# Speed: 3.4ms preprocess, 2338.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3 referees, 2318.2ms
# Speed: 3.4ms preprocess, 2318.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2316.0ms
# Speed: 3.2ms preprocess, 2316.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2755.9ms
# Speed: 3.8ms preprocess, 2755.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2849.2ms
# Speed: 4.4ms preprocess, 2849.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1 referee, 2322.8ms
# Speed: 4.2ms preprocess, 2322.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2319.4ms
# Speed: 3.0ms preprocess, 2319.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 2292.6ms
# Speed: 4.5ms preprocess, 2292.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2790.5ms
# Speed: 3.7ms preprocess, 2790.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 1 referee, 2819.3ms
# Speed: 4.4ms preprocess, 2819.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 2328.7ms
# Speed: 4.0ms preprocess, 2328.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 11 players, 1 referee, 2348.3ms
# Speed: 3.5ms preprocess, 2348.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2310.2ms
# Speed: 4.0ms preprocess, 2310.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2911.2ms
# Speed: 6.3ms preprocess, 2911.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 2736.5ms
# Speed: 6.1ms preprocess, 2736.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2301.6ms
# Speed: 3.8ms preprocess, 2301.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2338.3ms
# Speed: 5.8ms preprocess, 2338.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2363.3ms
# Speed: 3.9ms preprocess, 2363.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 7353.8ms
# Speed: 18.3ms preprocess, 7353.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2344.8ms
# Speed: 4.0ms preprocess, 2344.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2314.8ms
# Speed: 3.9ms preprocess, 2314.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2299.0ms
# Speed: 3.2ms preprocess, 2299.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2302.7ms
# Speed: 3.0ms preprocess, 2302.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 3264.7ms
# Speed: 6.0ms preprocess, 3264.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2353.8ms
# Speed: 3.7ms preprocess, 2353.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 12 players, 1 referee, 2309.2ms
# Speed: 3.3ms preprocess, 2309.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 2406.6ms
# Speed: 5.9ms preprocess, 2406.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 100 frames...
#
# 0: 384x640 12 players, 2369.2ms
# Speed: 4.1ms preprocess, 2369.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3358.5ms
# Speed: 4.1ms preprocess, 3358.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2305.1ms
# Speed: 3.9ms preprocess, 2305.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2364.8ms
# Speed: 6.5ms preprocess, 2364.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 2321.6ms
# Speed: 4.7ms preprocess, 2321.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 2346.1ms
# Speed: 5.4ms preprocess, 2346.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 3332.2ms
# Speed: 5.9ms preprocess, 3332.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2333.5ms
# Speed: 3.9ms preprocess, 2333.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 2317.4ms
# Speed: 3.4ms preprocess, 2317.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 2323.3ms
# Speed: 3.9ms preprocess, 2323.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 2 referees, 2302.3ms
# Speed: 5.7ms preprocess, 2302.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 3366.5ms
# Speed: 4.1ms preprocess, 3366.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2365.5ms
# Speed: 4.0ms preprocess, 2365.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2 referees, 2325.2ms
# Speed: 5.0ms preprocess, 2325.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 1 referee, 2372.7ms
# Speed: 4.4ms preprocess, 2372.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 2312.1ms
# Speed: 3.5ms preprocess, 2312.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 3337.1ms
# Speed: 5.8ms preprocess, 3337.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 2300.6ms
# Speed: 4.2ms preprocess, 2300.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2342.6ms
# Speed: 4.0ms preprocess, 2342.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2311.7ms
# Speed: 4.0ms preprocess, 2311.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2354.5ms
# Speed: 5.3ms preprocess, 2354.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3256.3ms
# Speed: 11.3ms preprocess, 3256.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2310.8ms
# Speed: 4.5ms preprocess, 2310.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 2306.6ms
# Speed: 4.2ms preprocess, 2306.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 2329.8ms
# Speed: 4.4ms preprocess, 2329.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 2377.7ms
# Speed: 4.2ms preprocess, 2377.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3224.6ms
# Speed: 4.7ms preprocess, 3224.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 2335.8ms
# Speed: 4.8ms preprocess, 2335.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 2316.4ms
# Speed: 4.6ms preprocess, 2316.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2297.7ms
# Speed: 4.3ms preprocess, 2297.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2371.0ms
# Speed: 4.6ms preprocess, 2371.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3226.3ms
# Speed: 3.9ms preprocess, 3226.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing tacticam video...
# Processing tacticam video...
#
# 0: 384x640 22 players, 2 referees, 2350.6ms
# Speed: 3.5ms preprocess, 2350.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2318.0ms
# Speed: 3.4ms preprocess, 2318.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2357.4ms
# Speed: 5.3ms preprocess, 2357.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2490.2ms
# Speed: 5.2ms preprocess, 2490.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 3263.2ms
# Speed: 4.1ms preprocess, 3263.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2373.7ms
# Speed: 3.8ms preprocess, 2373.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2370.9ms
# Speed: 3.9ms preprocess, 2370.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 2367.4ms
# Speed: 4.6ms preprocess, 2367.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 1 referee, 2589.9ms
# Speed: 3.6ms preprocess, 2589.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 2 referees, 2997.4ms
# Speed: 4.7ms preprocess, 2997.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2325.7ms
# Speed: 3.8ms preprocess, 2325.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2326.0ms
# Speed: 3.4ms preprocess, 2326.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2325.8ms
# Speed: 4.0ms preprocess, 2325.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2645.7ms
# Speed: 6.3ms preprocess, 2645.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2940.9ms
# Speed: 4.2ms preprocess, 2940.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 2414.3ms
# Speed: 5.4ms preprocess, 2414.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2395.0ms
# Speed: 4.1ms preprocess, 2395.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 3 referees, 2378.6ms
# Speed: 3.8ms preprocess, 2378.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2909.7ms
# Speed: 5.2ms preprocess, 2909.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2826.6ms
# Speed: 4.0ms preprocess, 2826.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2356.7ms
# Speed: 3.9ms preprocess, 2356.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2317.8ms
# Speed: 2.9ms preprocess, 2317.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2388.8ms
# Speed: 5.2ms preprocess, 2388.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3081.0ms
# Speed: 3.7ms preprocess, 3081.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2627.7ms
# Speed: 4.5ms preprocess, 2627.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2297.7ms
# Speed: 3.8ms preprocess, 2297.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2342.6ms
# Speed: 4.0ms preprocess, 2342.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2370.3ms
# Speed: 3.5ms preprocess, 2370.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3061.1ms
# Speed: 3.4ms preprocess, 3061.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2568.5ms
# Speed: 5.7ms preprocess, 2568.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 1 referee, 2314.2ms
# Speed: 4.0ms preprocess, 2314.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 2302.9ms
# Speed: 3.4ms preprocess, 2302.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 2335.4ms
# Speed: 6.0ms preprocess, 2335.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 1 referee, 3097.3ms
# Speed: 3.2ms preprocess, 3097.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2479.4ms
# Speed: 5.5ms preprocess, 2479.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 1 referee, 2337.6ms
# Speed: 4.3ms preprocess, 2337.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 2319.1ms
# Speed: 6.2ms preprocess, 2319.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 1 referee, 2304.3ms
# Speed: 4.2ms preprocess, 2304.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 3163.8ms
# Speed: 3.7ms preprocess, 3163.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 2440.3ms
# Speed: 3.9ms preprocess, 2440.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2314.6ms
# Speed: 3.8ms preprocess, 2314.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2338.3ms
# Speed: 4.5ms preprocess, 2338.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 2291.5ms
# Speed: 3.0ms preprocess, 2291.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 23 players, 3260.3ms
# Speed: 3.3ms preprocess, 3260.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2388.7ms
# Speed: 4.2ms preprocess, 2388.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2329.2ms
# Speed: 4.5ms preprocess, 2329.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2331.6ms
# Speed: 4.7ms preprocess, 2331.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2313.7ms
# Speed: 4.7ms preprocess, 2313.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 3336.7ms
# Speed: 4.9ms preprocess, 3336.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2335.7ms
# Speed: 4.0ms preprocess, 2335.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2321.9ms
# Speed: 4.6ms preprocess, 2321.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2330.9ms
# Speed: 4.6ms preprocess, 2330.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2334.9ms
# Speed: 5.5ms preprocess, 2334.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 3282.6ms
# Speed: 4.2ms preprocess, 3282.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2305.1ms
# Speed: 4.3ms preprocess, 2305.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 2329.5ms
# Speed: 5.0ms preprocess, 2329.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2329.8ms
# Speed: 4.5ms preprocess, 2329.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2297.2ms
# Speed: 3.2ms preprocess, 2297.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 3307.3ms
# Speed: 4.6ms preprocess, 3307.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 2307.7ms
# Speed: 4.2ms preprocess, 2307.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 2 referees, 2334.3ms
# Speed: 4.9ms preprocess, 2334.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2597.6ms
# Speed: 5.6ms preprocess, 2597.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2297.1ms
# Speed: 4.0ms preprocess, 2297.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 3271.6ms
# Speed: 3.3ms preprocess, 3271.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2298.0ms
# Speed: 3.9ms preprocess, 2298.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2288.5ms
# Speed: 4.1ms preprocess, 2288.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2287.6ms
# Speed: 3.8ms preprocess, 2287.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2287.5ms
# Speed: 4.5ms preprocess, 2287.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 3244.1ms
# Speed: 3.8ms preprocess, 3244.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2297.3ms
# Speed: 3.9ms preprocess, 2297.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2305.5ms
# Speed: 3.7ms preprocess, 2305.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2277.7ms
# Speed: 3.8ms preprocess, 2277.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2280.2ms
# Speed: 3.3ms preprocess, 2280.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 3256.2ms
# Speed: 4.0ms preprocess, 3256.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2293.6ms
# Speed: 3.1ms preprocess, 2293.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2294.8ms
# Speed: 4.0ms preprocess, 2294.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2290.0ms
# Speed: 3.9ms preprocess, 2290.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 23 players, 1 referee, 2289.6ms
# Speed: 4.6ms preprocess, 2289.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 3247.6ms
# Speed: 4.0ms preprocess, 3247.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2308.0ms
# Speed: 2.9ms preprocess, 2308.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2292.4ms
# Speed: 3.2ms preprocess, 2292.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 2289.5ms
# Speed: 3.0ms preprocess, 2289.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2308.1ms
# Speed: 2.9ms preprocess, 2308.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 1 referee, 3272.8ms
# Speed: 4.0ms preprocess, 3272.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2313.6ms
# Speed: 3.4ms preprocess, 2313.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2292.2ms
# Speed: 3.9ms preprocess, 2292.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2307.4ms
# Speed: 3.2ms preprocess, 2307.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2316.2ms
# Speed: 5.4ms preprocess, 2316.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 3299.7ms
# Speed: 4.0ms preprocess, 3299.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2292.3ms
# Speed: 3.1ms preprocess, 2292.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2291.6ms
# Speed: 4.2ms preprocess, 2291.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2295.6ms
# Speed: 5.6ms preprocess, 2295.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2281.1ms
# Speed: 3.1ms preprocess, 2281.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 3286.2ms
# Speed: 4.1ms preprocess, 3286.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2288.0ms
# Speed: 3.1ms preprocess, 2288.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2293.0ms
# Speed: 3.0ms preprocess, 2293.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2289.4ms
# Speed: 3.8ms preprocess, 2289.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2282.9ms
# Speed: 3.3ms preprocess, 2282.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 3 referees, 3302.7ms
# Speed: 3.3ms preprocess, 3302.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2280.1ms
# Speed: 3.1ms preprocess, 2280.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 100 frames...
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2286.2ms
# Speed: 2.8ms preprocess, 2286.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2275.8ms
# Speed: 3.6ms preprocess, 2275.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 2279.9ms
# Speed: 3.7ms preprocess, 2279.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 3294.9ms
# Speed: 3.8ms preprocess, 3294.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 2 referees, 2281.8ms
# Speed: 3.7ms preprocess, 2281.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 2277.3ms
# Speed: 3.7ms preprocess, 2277.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 2298.0ms
# Speed: 3.0ms preprocess, 2298.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 2281.7ms
# Speed: 4.1ms preprocess, 2281.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 3257.5ms
# Speed: 5.3ms preprocess, 3257.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 2287.8ms
# Speed: 4.0ms preprocess, 2287.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2291.2ms
# Speed: 3.0ms preprocess, 2291.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2320.6ms
# Speed: 3.7ms preprocess, 2320.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2290.7ms
# Speed: 3.6ms preprocess, 2290.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 3273.9ms
# Speed: 3.2ms preprocess, 3273.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2279.2ms
# Speed: 3.0ms preprocess, 2279.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 2275.1ms
# Speed: 4.0ms preprocess, 2275.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2273.5ms
# Speed: 3.4ms preprocess, 2273.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2283.8ms
# Speed: 2.9ms preprocess, 2283.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 3300.7ms
# Speed: 6.1ms preprocess, 3300.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 2284.0ms
# Speed: 5.5ms preprocess, 2284.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 2280.3ms
# Speed: 3.2ms preprocess, 2280.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 2292.7ms
# Speed: 3.1ms preprocess, 2292.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 2294.3ms
# Speed: 3.2ms preprocess, 2294.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 3344.1ms
# Speed: 3.7ms preprocess, 3344.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2324.6ms
# Speed: 3.5ms preprocess, 2324.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 2329.5ms
# Speed: 3.0ms preprocess, 2329.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2313.3ms
# Speed: 3.3ms preprocess, 2313.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 2 referees, 2344.5ms
# Speed: 4.8ms preprocess, 2344.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 2 referees, 3300.8ms
# Speed: 3.6ms preprocess, 3300.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2298.8ms
# Speed: 2.9ms preprocess, 2298.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2323.5ms
# Speed: 3.1ms preprocess, 2323.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 2 referees, 2321.9ms
# Speed: 4.1ms preprocess, 2321.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2299.3ms
# Speed: 3.8ms preprocess, 2299.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 3302.4ms
# Speed: 4.0ms preprocess, 3302.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 2344.2ms
# Speed: 4.1ms preprocess, 2344.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 1 referee, 2292.6ms
# Speed: 3.9ms preprocess, 2292.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 1 referee, 2328.8ms
# Speed: 3.9ms preprocess, 2328.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2318.0ms
# Speed: 3.9ms preprocess, 2318.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 3342.4ms
# Speed: 5.3ms preprocess, 3342.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 2294.9ms
# Speed: 3.8ms preprocess, 2294.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 2310.5ms
# Speed: 3.4ms preprocess, 2310.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 2317.4ms
# Speed: 4.1ms preprocess, 2317.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 2314.4ms
# Speed: 4.1ms preprocess, 2314.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 3321.3ms
# Speed: 4.8ms preprocess, 3321.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 2306.8ms
# Speed: 4.0ms preprocess, 2306.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 2321.9ms
# Speed: 4.8ms preprocess, 2321.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 3 referees, 2340.5ms
# Speed: 3.7ms preprocess, 2340.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2300.0ms
# Speed: 4.4ms preprocess, 2300.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 23 players, 2 referees, 3265.5ms
# Speed: 4.0ms preprocess, 3265.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 2310.8ms
# Speed: 4.1ms preprocess, 2310.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 2328.2ms
# Speed: 3.2ms preprocess, 2328.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 2305.6ms
# Speed: 3.9ms preprocess, 2305.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 3 referees, 2328.1ms
# Speed: 3.9ms preprocess, 2328.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 3327.7ms
# Speed: 3.9ms preprocess, 3327.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 2329.2ms
# Speed: 3.5ms preprocess, 2329.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 2305.6ms
# Speed: 4.2ms preprocess, 2305.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 2318.7ms
# Speed: 5.9ms preprocess, 2318.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 2323.4ms
# Speed: 3.8ms preprocess, 2323.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 3329.2ms
# Speed: 5.0ms preprocess, 3329.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 2301.2ms
# Speed: 3.9ms preprocess, 2301.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 2302.2ms
# Speed: 3.1ms preprocess, 2302.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 3 referees, 2315.4ms
# Speed: 3.1ms preprocess, 2315.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 2 referees, 2340.7ms
# Speed: 3.8ms preprocess, 2340.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 3261.5ms
# Speed: 4.3ms preprocess, 3261.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 2363.4ms
# Speed: 5.3ms preprocess, 2363.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 2309.4ms
# Speed: 4.2ms preprocess, 2309.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 2330.4ms
# Speed: 4.1ms preprocess, 2330.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 2354.6ms
# Speed: 4.2ms preprocess, 2354.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 3244.5ms
# Speed: 8.0ms preprocess, 3244.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 2352.6ms
# Speed: 4.7ms preprocess, 2352.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2337.0ms
# Speed: 3.2ms preprocess, 2337.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2336.2ms
# Speed: 4.5ms preprocess, 2336.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 2533.8ms
# Speed: 3.6ms preprocess, 2533.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 3079.5ms
# Speed: 8.2ms preprocess, 3079.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 2304.8ms
# Speed: 4.7ms preprocess, 2304.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2334.8ms
# Speed: 3.4ms preprocess, 2334.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2300.9ms
# Speed: 3.0ms preprocess, 2300.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2612.3ms
# Speed: 6.3ms preprocess, 2612.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 3022.5ms
# Speed: 4.2ms preprocess, 3022.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 2329.8ms
# Speed: 2.9ms preprocess, 2329.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 2319.4ms
# Speed: 4.4ms preprocess, 2319.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2345.1ms
# Speed: 5.8ms preprocess, 2345.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 2651.2ms
# Speed: 3.5ms preprocess, 2651.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 3282.9ms
# Speed: 4.2ms preprocess, 3282.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 3983.4ms
# Speed: 15.8ms preprocess, 3983.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 2377.8ms
# Speed: 4.1ms preprocess, 2377.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 2433.2ms
# Speed: 2.8ms preprocess, 2433.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 3132.2ms
# Speed: 4.2ms preprocess, 3132.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 1 referee, 2298.9ms
# Speed: 4.1ms preprocess, 2298.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 2 referees, 2316.3ms
# Speed: 5.6ms preprocess, 2316.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 2284.7ms
# Speed: 3.7ms preprocess, 2284.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 3 referees, 2462.1ms
# Speed: 5.4ms preprocess, 2462.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 3155.6ms
# Speed: 5.6ms preprocess, 3155.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 2872.0ms
# Speed: 3.8ms preprocess, 2872.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 2297.7ms
# Speed: 3.9ms preprocess, 2297.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 2310.4ms
# Speed: 5.8ms preprocess, 2310.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 7426.8ms
# Speed: 3.9ms preprocess, 7426.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 3817.2ms
# Speed: 4.7ms preprocess, 3817.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 2329.2ms
# Speed: 4.3ms preprocess, 2329.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 2 referees, 2332.1ms
# Speed: 3.5ms preprocess, 2332.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 200 frames...
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 2404.8ms
# Speed: 3.6ms preprocess, 2404.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Mapping players across cameras...
# Found 15 player mappings:
# Broadcast Player 0 -> Tacticam Player 21
# Broadcast Player 1 -> Tacticam Player 13
# Broadcast Player 3 -> Tacticam Player 0
# Broadcast Player 7 -> Tacticam Player 9
# Broadcast Player 8 -> Tacticam Player 18
# Broadcast Player 9 -> Tacticam Player 14
# Broadcast Player 10 -> Tacticam Player 3
# Broadcast Player 12 -> Tacticam Player 1
# Broadcast Player 13 -> Tacticam Player 8
# Broadcast Player 14 -> Tacticam Player 23
# Broadcast Player 15 -> Tacticam Player 11
# Broadcast Player 17 -> Tacticam Player 12
# Broadcast Player 18 -> Tacticam Player 5
# Broadcast Player 20 -> Tacticam Player 24
# Broadcast Player 22 -> Tacticam Player 15
# Results saved to results
# Cross-camera player mapping completed!

# %%
import cv2
import torch
import numpy as np
from ultralytics import YOLO
import pickle
from sklearn.preprocessing import LabelEncoder
from scipy.optimize import linear_sum_assignment
from sklearn.metrics.pairwise import cosine_similarity
import os
import json
from collections import defaultdict, defaultdict
import matplotlib.pyplot as plt

class PlayerReIDFeatures:
    """Feature extraction for player re-identification"""

    def __init__(self):
        self.color_bins = 8
        self.label_encoder = LabelEncoder()

    def extract_appearance_features(self, frame, bbox):
        """Extract appearance-based features"""
        x1, y1, x2, y2 = bbox[:4]  # Ensure only first four values are used
        if x1 >= x2 or y1 >= y2 or x1 < 0 or y1 < 0 or x2 > frame.shape[1] or y2 > frame.shape[0]:
            return None

        # Crop player region
        player_crop = frame[y1:y2, x1:x2]
        if player_crop.size == 0:
            return None

        # Resize for consistency
        player_crop = cv2.resize(player_crop, (64, 128))

        # Convert to HSV
        hsv = cv2.cvtColor(player_crop, cv2.COLOR_BGR2HSV)
        hist_h = cv2.calcHist([hsv], [0], None, [self.color_bins], [0, 180])
        hist_s = cv2.calcHist([hsv], [1], None, [self.color_bins], [0, 256])
        hist_v = cv2.calcHist([hsv], [2], None, [self.color_bins], [0, 256])

        # Normalize histograms
        hist_h = cv2.normalize(hist_h, hist_h).flatten()
        hist_s = cv2.normalize(hist_s, hist_s).flatten()
        hist_v = cv2.normalize(hist_v, hist_v).flatten()

        # Combine color features
        color_features = np.concatenate([hist_h, hist_s, hist_v])

        # Texture features
        gray = cv2.cvtColor(player_crop, cv2.COLOR_BGR2GRAY)
        texture_features = self.extract_texture_features(gray)

        # Combine all appearance features
        return np.concatenate([color_features, texture_features])

    def extract_texture_features(self, gray_image):
        """Extract simple texture features"""
        # Calculate gradients
        grad_x = cv2.Sobel(gray_image, cv2.CV_64F, 1, 0, ksize=3)
        grad_y = cv2.Sobel(gray_image, cv2.CV_64F, 0, 1, ksize=3)

        # Gradient magnitude
        magnitude = np.sqrt(grad_x**2 + grad_y**2)

        # Texture statistics
        texture_stats = [
            np.mean(magnitude),
            np.std(magnitude),
            np.mean(gray_image),
            np.std(gray_image)
        ]

        return np.array(texture_stats)

    def extract_spatial_features(self, frame, bbox):
        """Extract spatial/positional features"""
        x1, y1, x2, y2 = bbox[:4]
        h, w = frame.shape[:2]

        center_x = ((x1 + x2) / 2) / w
        center_y = ((y1 + y2) / 2) / h
        bbox_w = (x2 - x1) / w
        bbox_h = (y2 - y1) / h
        aspect_ratio = bbox_w / bbox_h if bbox_h > 0 else 0.0
        return np.array([center_x, center_y, bbox_w, bbox_h, aspect_ratio])

class PlayerTracker:
    """Player tracking with re-identification capabilities"""

    def __init__(self, model_path, max_disappeared=30, max_distance=100):
        self.model = YOLO(model_path)
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model.to(self.device)
        self.feature_extractor = PlayerReIDFeatures()

        self.max_disappeared = max_disappeared
        self.max_distance = max_distance

        self.next_id = 0
        self.active_players = {}
        self.disappeared_players = {}
        self.player_features = {}
        self.tracking_history = defaultdict(list)

        self.feature_history_size = 10
        self.reid_threshold = 0.6

    def detect_players(self, frame):
        """Detect players in frame"""
        results = self.model(frame, imgsz=640)  # Optimize inference speed
        detections = []

        for result in results:
            boxes = result.boxes
            if boxes is not None:
                for box in boxes:
                    # Include players and referees (adjust class IDs as needed)
                    if int(box.cls) in [0, 2]:  # 0: player, 2: referee
                        xyxy = box.xyxy[0].cpu().numpy()
                        conf = box.conf[0].cpu().numpy()
                        if conf > 0.5:
                            detections.append([int(xyxy[0]), int(xyxy[1]), int(xyxy[2]), int(xyxy[3]), conf])

        return detections

    def calculate_distance(self, bbox1, bbox2):
        """Calculate distance between two bounding boxes"""
        center1 = [(bbox1[0] + bbox1[2]) / 2, (bbox1[1] + bbox1[3]) / 2]
        center2 = [(bbox2[0] + bbox2[2]) / 2, (bbox2[1] + bbox2[3]) / 2]

        return np.sqrt((center1[0] - center2[0])**2 + (center1[1] - center2[1])**2)

    def calculate_feature_similarity(self, features1, features2):
        """Calculate similarity between feature vectors"""
        if features1 is None or features2 is None:
            return 0.0

        app_feat1 = features1[:-5]
        app_feat2 = features2[:-5]
        spatial_feat1 = features1[-5:]
        spatial_feat2 = features2[-5:]

        app_sim = cosine_similarity([app_feat1], [app_feat2])[0][0]
        spatial_sim = 1.0 / (1.0 + np.linalg.norm(spatial_feat1 - spatial_feat2))

        total_sim = 0.8 * app_sim + 0.2 * spatial_sim
        return max(0.0, total_sim)

    def extract_player_features(self, frame, bbox):
        """Extract comprehensive features for a player"""
        app_features = self.feature_extractor.extract_appearance_features(frame, bbox)
        if app_features is None:
            return None

        spatial_features = self.feature_extractor.extract_spatial_features(frame, bbox)
        return np.concatenate([app_features, spatial_features])

    def update_player_features(self, player_id, features):
        """Update feature history for a player"""
        if player_id not in self.player_features:
            self.player_features[player_id] = deque(maxlen=self.feature_history_size)
        self.player_features[player_id].append(features)

    def get_average_features(self, player_id):
        """Get average features for a player"""
        if player_id not in self.player_features or len(self.player_features[player_id]) == 0:
            return None
        return np.mean(list(self.player_features[player_id]), axis=0)

    def find_best_reid_match(self, features):
        """Find best re-identification match among disappeared players"""
        best_match_id = None
        best_similarity = 0.0

        for player_id in self.disappeared_players:
            avg_features = self.get_average_features(player_id)
            if avg_features is not None:
                similarity = self.calculate_feature_similarity(features, avg_features)
                if similarity > best_similarity and similarity > self.reid_threshold:
                    best_similarity = similarity
                    best_match_id = player_id

        return best_match_id, best_similarity

    def track_players(self, frame, frame_number):
        """Main tracking function"""
        detections = self.detect_players(frame)
        detection_features = [self.extract_player_features(frame, det) for det in detections]

        if len(self.active_players) == 0:
            for i, detection in enumerate(detections):
                if detection_features[i] is not None:
                    player_id = self.next_id
                    self.next_id += 1
                    self.active_players[player_id] = detection
                    self.update_player_features(player_id, detection_features[i])
                    self.tracking_history[player_id].append({
                        'frame': frame_number,
                        'bbox': detection,
                        'features': detection_features[i]
                    })
            return self.active_players

        active_player_ids = list(self.active_players.keys())
        cost_matrix = np.full((len(active_player_ids), len(detections)), 1000.0)

        for i, player_id in enumerate(active_player_ids):
            player_features = self.get_average_features(player_id)
            player_bbox = self.active_players[player_id]

            for j, detection in enumerate(detections):
                if detection_features[j] is not None:
                    distance = self.calculate_distance(player_bbox, detection)
                    distance_cost = distance / self.max_distance
                    similarity = self.calculate_feature_similarity(player_features, detection_features[j])
                    feature_cost = 1.0 - similarity
                    if distance < self.max_distance:
                        cost_matrix[i, j] = 0.7 * distance_cost + 0.3 * feature_cost

        if cost_matrix.size > 0:
            row_indices, col_indices = linear_sum_assignment(cost_matrix)
            new_active_players = {}
            used_detections = set()

            for row, col in zip(row_indices, col_indices):
                if cost_matrix[row, col] < 0.5:
                    player_id = active_player_ids[row]
                    detection = detections[col]
                    new_active_players[player_id] = detection
                    used_detections.add(col)
                    if detection_features[col] is not None:
                        self.update_player_features(player_id, detection_features[col])
                        self.tracking_history[player_id].append({
                            'frame': frame_number,
                            'bbox': detection,
                            'features': detection_features[col]
                        })

            for i, player_id in enumerate(active_player_ids):
                if i not in row_indices or cost_matrix[i, col_indices[list(row_indices).index(i)]] >= 0.5:
                    self.disappeared_players[player_id] = 0

            for j, detection in enumerate(detections):
                if j not in used_detections and detection_features[j] is not None:
                    reid_match, similarity = self.find_best_reid_match(detection_features[j])
                    if reid_match is not None:
                        new_active_players[reid_match] = detection
                        del self.disappeared_players[reid_match]
                        self.update_player_features(reid_match, detection_features[j])
                        self.tracking_history[reid_match].append({
                            'frame': frame_number,
                            'bbox': detection,
                            'features': detection_features[j],
                            'reidentified': True
                        })
                    else:
                        player_id = self.next_id
                        self.next_id += 1
                        new_active_players[player_id] = detection
                        self.update_player_features(player_id, detection_features[j])
                        self.tracking_history[player_id].append({
                            'frame': frame_number,
                            'bbox': detection,
                            'features': detection_features[j]
                        })

            self.active_players = new_active_players

        to_remove = []
        for player_id in self.disappeared_players:
            self.disappeared_players[player_id] += 1
            if self.disappeared_players[player_id] > self.max_disappeared:
                to_remove.append(player_id)
        for player_id in to_remove:
            del self.disappeared_players[player_id]

        return self.active_players

    def process_video(self, video_path, output_path=None):
        """Process entire video with tracking and re-identification"""
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            raise ValueError(f"Could not open video: {video_path}")

        fps = int(cap.get(cv2.CAP_PROP_FPS))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

        if output_path:
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

        frame_number = 0
        print(f"Processing video: {total_frames} frames at {fps} FPS")

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            active_players = self.track_players(frame, frame_number)
            for player_id, bbox in active_players.items():
                x1, y1, x2, y2 = bbox[:4]
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, f'Player {player_id}', (x1, y1-10),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
            if output_path:
                out.write(frame)

            frame_number += 1
            if frame_number % 100 == 0:
                print(f"Processed {frame_number}/{total_frames} frames ({frame_number/total_frames*100:.1f}%)")

        cap.release()
        if output_path:
            out.release()

        print(f"Video processing completed. Total unique players tracked: {self.next_id}")
        return self.tracking_history

    def save_results(self, output_dir):
        """Save tracking results and statistics"""
        os.makedirs(output_dir, exist_ok=True)

        tracking_data = {}
        for player_id, history in self.tracking_history.items():
            tracking_data[player_id] = []
            for entry in history:
                entry_copy = entry.copy()
                if 'features' in entry_copy:
                    entry_copy['features'] = entry_copy['features'].tolist()
                tracking_data[player_id].append(entry_copy)

        with open(os.path.join(output_dir, 'tracking_summary.json'), 'w') as f:
            json.dump(tracking_data, f, indent=2)

        with open(os.path.join(output_dir, 'player_features.pkl'), 'wb') as f:
            pickle.dump(dict(self.player_features), f)

        stats = self.generate_statistics()
        with open(os.path.join(output_dir, 'tracking_statistics.json'), 'w') as f:
            json.dump(stats, f, indent=2)

        print(f"Results saved to {output_dir}")

    def generate_statistics(self):
        """Generate tracking statistics"""
        stats = {
            'total_players': self.next_id,
            'player_statistics': {}
        }

        for player_id, history in self.tracking_history.items():
            player_stats = {
                'total_detections': len(history),
                'first_frame': history[0]['frame'] if history else 0,
                'last_frame': history[-1]['frame'] if history else 0,
                'reidentification_events': sum(1 for entry in history if entry.get('reidentified', False))
            }
            player_stats['tracking_duration'] = player_stats['last_frame'] - player_stats['first_frame'] if len(history) > 1 else 0
            stats['player_statistics'][player_id] = player_stats

        return stats

    def visualize_tracking_paths(self, video_path, output_path, max_frames=300):
        """Create visualization of player tracking paths"""
        cap = cv2.VideoCapture(video_path)
        ret, frame = cap.read()
        cap.release()

        if not ret:
            return

        canvas = frame.copy()
        colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0),
                 (255, 0, 255), (0, 255, 255), (128, 0, 128), (255, 165, 0)]

        for player_id, history in self.tracking_history.items():
            if len(history) < 2:
                continue
            color = colors[player_id % len(colors)]
            centers = []
            for entry in history[:max_frames]:
                bbox = entry['bbox']
                center = ((bbox[0] + bbox[2]) // 2, (bbox[1] + bbox[3]) // 2)
                centers.append(center)
            for i in range(len(centers) - 1):
                cv2.line(canvas, centers[i], centers[i + 1], color, 2)
            if centers:
                cv2.circle(canvas, centers[0], 5, color, -1)
                cv2.circle(canvas, centers[-1], 8, color, 3)
                cv2.putText(canvas, f'P{player_id}', (centers[0][0] + 10, centers[0][1] - 10),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        cv2.imwrite(output_path, canvas)

def main():
    # Configuration
    MODEL_PATH = "best.pt"  # Relative path
    INPUT_VIDEO = "15sec_input_720p.mp4"
    OUTPUT_VIDEO = "tracked_output.mp4"
    OUTPUT_DIR = "tracking_results"

    tracker = PlayerTracker(MODEL_PATH, max_disappeared=30, max_distance=150)
    print("Starting player tracking and re-identification...")
    tracking_history = tracker.process_video(INPUT_VIDEO, OUTPUT_VIDEO)
    tracker.save_results(OUTPUT_DIR)
    tracker.visualize_tracking_paths(INPUT_VIDEO, os.path.join(OUTPUT_DIR, 'tracking_paths.jpg'))

    stats = tracker.generate_statistics()
    print(f"\nTracking Summary:")
    print(f"Total players tracked: {stats['total_players']}")
    for player_id, player_stats in stats['player_statistics'].items():
        print(f"Player {player_id}: {player_stats['total_detections']} detections, "
              f"{player_stats['tracking_duration']} frames duration, "
              f"{player_stats['reidentification_events']} re-ID events")
    print(f"\nOutput video saved as: {OUTPUT_VIDEO}")
    print(f"Detailed results saved in: {OUTPUT_DIR}")

if __name__ == "__main__":
    main()
# Out:
# Starting player tracking and re-identification...
# Processing video: 375 frames at 25 FPS
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2308.5ms
# Speed: 4.5ms preprocess, 2308.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 2613.8ms
# Speed: 3.1ms preprocess, 2613.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2888.7ms
# Speed: 3.0ms preprocess, 2888.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2286.3ms
# Speed: 2.9ms preprocess, 2286.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2297.4ms
# Speed: 3.9ms preprocess, 2297.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2314.7ms
# Speed: 3.1ms preprocess, 2314.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2949.9ms
# Speed: 3.0ms preprocess, 2949.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 2534.4ms
# Speed: 5.0ms preprocess, 2534.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 2294.5ms
# Speed: 4.2ms preprocess, 2294.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2298.2ms
# Speed: 3.6ms preprocess, 2298.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2309.4ms
# Speed: 3.0ms preprocess, 2309.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 3245.5ms
# Speed: 3.2ms preprocess, 3245.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 2283.0ms
# Speed: 4.9ms preprocess, 2283.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2306.3ms
# Speed: 3.0ms preprocess, 2306.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2287.2ms
# Speed: 4.4ms preprocess, 2287.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 2277.4ms
# Speed: 3.0ms preprocess, 2277.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 3315.4ms
# Speed: 3.1ms preprocess, 3315.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2269.4ms
# Speed: 3.1ms preprocess, 2269.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2284.6ms
# Speed: 2.6ms preprocess, 2284.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2289.2ms
# Speed: 2.9ms preprocess, 2289.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 2285.5ms
# Speed: 3.0ms preprocess, 2285.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 3245.7ms
# Speed: 2.9ms preprocess, 3245.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2292.0ms
# Speed: 3.1ms preprocess, 2292.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2299.9ms
# Speed: 3.1ms preprocess, 2299.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2307.2ms
# Speed: 3.9ms preprocess, 2307.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2531.0ms
# Speed: 2.9ms preprocess, 2531.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2970.2ms
# Speed: 3.2ms preprocess, 2970.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 2307.9ms
# Speed: 3.4ms preprocess, 2307.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 2 referees, 2277.2ms
# Speed: 3.5ms preprocess, 2277.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 16 players, 2 referees, 2285.2ms
# Speed: 3.0ms preprocess, 2285.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 15 players, 2 referees, 2766.0ms
# Speed: 2.9ms preprocess, 2766.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2683.0ms
# Speed: 3.0ms preprocess, 2683.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2278.5ms
# Speed: 3.0ms preprocess, 2278.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2308.0ms
# Speed: 2.3ms preprocess, 2308.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2284.8ms
# Speed: 3.1ms preprocess, 2284.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3 referees, 3015.8ms
# Speed: 3.1ms preprocess, 3015.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2470.6ms
# Speed: 5.9ms preprocess, 2470.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2291.7ms
# Speed: 3.0ms preprocess, 2291.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2297.2ms
# Speed: 3.0ms preprocess, 2297.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 2336.6ms
# Speed: 3.2ms preprocess, 2336.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 3 referees, 3263.5ms
# Speed: 2.4ms preprocess, 3263.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 2292.2ms
# Speed: 3.0ms preprocess, 2292.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2302.0ms
# Speed: 3.2ms preprocess, 2302.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2287.2ms
# Speed: 3.1ms preprocess, 2287.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 2320.1ms
# Speed: 3.4ms preprocess, 2320.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 3161.8ms
# Speed: 3.1ms preprocess, 3161.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 2285.1ms
# Speed: 3.1ms preprocess, 2285.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2302.1ms
# Speed: 2.9ms preprocess, 2302.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2310.3ms
# Speed: 4.0ms preprocess, 2310.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 2670.1ms
# Speed: 2.7ms preprocess, 2670.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 2846.7ms
# Speed: 4.9ms preprocess, 2846.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 3 referees, 2313.9ms
# Speed: 3.4ms preprocess, 2313.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2288.0ms
# Speed: 3.5ms preprocess, 2288.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 2284.2ms
# Speed: 4.6ms preprocess, 2284.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 3057.5ms
# Speed: 2.9ms preprocess, 3057.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 2437.2ms
# Speed: 3.2ms preprocess, 2437.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2307.4ms
# Speed: 2.9ms preprocess, 2307.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2290.1ms
# Speed: 3.1ms preprocess, 2290.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2289.3ms
# Speed: 3.8ms preprocess, 2289.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 3281.5ms
# Speed: 2.9ms preprocess, 3281.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2306.5ms
# Speed: 4.3ms preprocess, 2306.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2287.8ms
# Speed: 2.8ms preprocess, 2287.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2320.1ms
# Speed: 4.0ms preprocess, 2320.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2296.2ms
# Speed: 4.1ms preprocess, 2296.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 3209.5ms
# Speed: 3.1ms preprocess, 3209.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 4 referees, 2290.8ms
# Speed: 3.1ms preprocess, 2290.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 2272.2ms
# Speed: 2.9ms preprocess, 2272.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 4 referees, 2294.8ms
# Speed: 2.9ms preprocess, 2294.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2539.9ms
# Speed: 2.6ms preprocess, 2539.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2926.9ms
# Speed: 4.7ms preprocess, 2926.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2295.0ms
# Speed: 2.8ms preprocess, 2295.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2283.3ms
# Speed: 2.9ms preprocess, 2283.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2296.9ms
# Speed: 3.1ms preprocess, 2296.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2906.2ms
# Speed: 2.6ms preprocess, 2906.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2653.8ms
# Speed: 2.9ms preprocess, 2653.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2282.9ms
# Speed: 3.1ms preprocess, 2282.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2321.2ms
# Speed: 2.7ms preprocess, 2321.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 2305.2ms
# Speed: 2.8ms preprocess, 2305.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 3228.6ms
# Speed: 2.5ms preprocess, 3228.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2319.4ms
# Speed: 3.1ms preprocess, 2319.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2291.5ms
# Speed: 3.0ms preprocess, 2291.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2309.5ms
# Speed: 3.8ms preprocess, 2309.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2311.1ms
# Speed: 3.2ms preprocess, 2311.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 3284.2ms
# Speed: 2.9ms preprocess, 3284.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2305.9ms
# Speed: 4.2ms preprocess, 2305.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2315.8ms
# Speed: 3.1ms preprocess, 2315.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2289.4ms
# Speed: 3.0ms preprocess, 2289.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2352.5ms
# Speed: 2.7ms preprocess, 2352.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 3167.4ms
# Speed: 3.1ms preprocess, 3167.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2306.1ms
# Speed: 3.2ms preprocess, 2306.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 2305.1ms
# Speed: 3.0ms preprocess, 2305.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 2302.6ms
# Speed: 3.3ms preprocess, 2302.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2763.7ms
# Speed: 3.4ms preprocess, 2763.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 2739.9ms
# Speed: 3.0ms preprocess, 2739.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 2391.7ms
# Speed: 3.3ms preprocess, 2391.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2410.4ms
# Speed: 3.7ms preprocess, 2410.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2450.5ms
# Speed: 3.0ms preprocess, 2450.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 3452.5ms
# Speed: 3.0ms preprocess, 3452.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 2413.4ms
# Speed: 3.2ms preprocess, 2413.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2376.1ms
# Speed: 5.6ms preprocess, 2376.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed 100/375 frames (26.7%)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2452.0ms
# Speed: 9.0ms preprocess, 2452.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 2793.9ms
# Speed: 5.0ms preprocess, 2793.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2970.3ms
# Speed: 4.4ms preprocess, 2970.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2375.7ms
# Speed: 3.2ms preprocess, 2375.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2395.8ms
# Speed: 3.1ms preprocess, 2395.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2394.9ms
# Speed: 3.4ms preprocess, 2394.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 3450.2ms
# Speed: 3.1ms preprocess, 3450.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 2392.0ms
# Speed: 3.0ms preprocess, 2392.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2381.6ms
# Speed: 2.9ms preprocess, 2381.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2365.5ms
# Speed: 4.4ms preprocess, 2365.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 17 players, 2446.3ms
# Speed: 4.6ms preprocess, 2446.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 3262.9ms
# Speed: 3.0ms preprocess, 3262.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 2386.6ms
# Speed: 3.1ms preprocess, 2386.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2423.6ms
# Speed: 3.3ms preprocess, 2423.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 2413.8ms
# Speed: 3.0ms preprocess, 2413.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 3038.5ms
# Speed: 2.9ms preprocess, 3038.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 2698.3ms
# Speed: 3.2ms preprocess, 2698.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 2420.5ms
# Speed: 3.5ms preprocess, 2420.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 2386.0ms
# Speed: 2.8ms preprocess, 2386.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 2386.6ms
# Speed: 6.6ms preprocess, 2386.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 3388.0ms
# Speed: 2.6ms preprocess, 3388.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 2425.7ms
# Speed: 2.9ms preprocess, 2425.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 2431.7ms
# Speed: 3.5ms preprocess, 2431.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 2368.2ms
# Speed: 2.9ms preprocess, 2368.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 2779.0ms
# Speed: 2.6ms preprocess, 2779.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 2831.3ms
# Speed: 3.0ms preprocess, 2831.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 3527.1ms
# Speed: 3.5ms preprocess, 3527.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 3845.7ms
# Speed: 9.0ms preprocess, 3845.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 3290.9ms
# Speed: 2.6ms preprocess, 3290.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 2291.8ms
# Speed: 3.0ms preprocess, 2291.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 2284.0ms
# Speed: 2.5ms preprocess, 2284.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 2324.8ms
# Speed: 3.0ms preprocess, 2324.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 18 players, 1 referee, 2503.0ms
# Speed: 3.0ms preprocess, 2503.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 3003.9ms
# Speed: 3.3ms preprocess, 3003.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 2307.1ms
# Speed: 2.7ms preprocess, 2307.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 2292.3ms
# Speed: 3.1ms preprocess, 2292.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 2287.4ms
# Speed: 4.8ms preprocess, 2287.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 2776.8ms
# Speed: 2.8ms preprocess, 2776.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 1 referee, 2779.9ms
# Speed: 3.0ms preprocess, 2779.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 2304.6ms
# Speed: 3.2ms preprocess, 2304.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 2317.5ms
# Speed: 2.8ms preprocess, 2317.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 2329.6ms
# Speed: 3.0ms preprocess, 2329.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 3096.8ms
# Speed: 3.1ms preprocess, 3096.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 2454.3ms
# Speed: 3.0ms preprocess, 2454.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 2296.7ms
# Speed: 3.0ms preprocess, 2296.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2293.5ms
# Speed: 3.1ms preprocess, 2293.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 2303.3ms
# Speed: 2.9ms preprocess, 2303.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 3322.3ms
# Speed: 2.9ms preprocess, 3322.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 2290.8ms
# Speed: 3.1ms preprocess, 2290.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 2317.7ms
# Speed: 3.2ms preprocess, 2317.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 2285.3ms
# Speed: 3.1ms preprocess, 2285.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 2295.8ms
# Speed: 2.9ms preprocess, 2295.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 3266.5ms
# Speed: 2.7ms preprocess, 3266.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 2312.0ms
# Speed: 3.2ms preprocess, 2312.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 2301.2ms
# Speed: 2.7ms preprocess, 2301.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 2287.1ms
# Speed: 3.1ms preprocess, 2287.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2385.1ms
# Speed: 3.3ms preprocess, 2385.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 3101.7ms
# Speed: 3.0ms preprocess, 3101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2281.4ms
# Speed: 2.8ms preprocess, 2281.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 2278.5ms
# Speed: 2.5ms preprocess, 2278.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 2285.6ms
# Speed: 2.8ms preprocess, 2285.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 2646.0ms
# Speed: 3.0ms preprocess, 2646.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2845.6ms
# Speed: 3.3ms preprocess, 2845.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2300.5ms
# Speed: 2.7ms preprocess, 2300.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2281.0ms
# Speed: 2.6ms preprocess, 2281.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2293.7ms
# Speed: 3.2ms preprocess, 2293.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2843.1ms
# Speed: 2.9ms preprocess, 2843.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2714.6ms
# Speed: 3.0ms preprocess, 2714.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2299.8ms
# Speed: 3.1ms preprocess, 2299.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2294.9ms
# Speed: 3.0ms preprocess, 2294.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 2287.3ms
# Speed: 3.1ms preprocess, 2287.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 3069.0ms
# Speed: 2.6ms preprocess, 3069.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 2445.7ms
# Speed: 3.1ms preprocess, 2445.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 2285.9ms
# Speed: 2.8ms preprocess, 2285.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2282.1ms
# Speed: 2.9ms preprocess, 2282.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2288.3ms
# Speed: 3.0ms preprocess, 2288.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3290.1ms
# Speed: 3.2ms preprocess, 3290.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2305.5ms
# Speed: 11.2ms preprocess, 2305.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 2300.9ms
# Speed: 2.9ms preprocess, 2300.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 11 players, 1 referee, 2285.3ms
# Speed: 2.8ms preprocess, 2285.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 2317.3ms
# Speed: 2.7ms preprocess, 2317.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 3288.0ms
# Speed: 2.5ms preprocess, 3288.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2290.5ms
# Speed: 3.3ms preprocess, 2290.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 2303.4ms
# Speed: 3.1ms preprocess, 2303.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2325.0ms
# Speed: 8.2ms preprocess, 2325.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2353.9ms
# Speed: 2.9ms preprocess, 2353.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 3142.2ms
# Speed: 3.0ms preprocess, 3142.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2313.5ms
# Speed: 2.8ms preprocess, 2313.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 2302.8ms
# Speed: 2.5ms preprocess, 2302.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1 referee, 2331.7ms
# Speed: 3.0ms preprocess, 2331.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 2630.9ms
# Speed: 3.1ms preprocess, 2630.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2911.7ms
# Speed: 2.9ms preprocess, 2911.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2297.3ms
# Speed: 3.0ms preprocess, 2297.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 14 players, 2298.0ms
# Speed: 3.3ms preprocess, 2298.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2297.1ms
# Speed: 2.9ms preprocess, 2297.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2872.2ms
# Speed: 2.4ms preprocess, 2872.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2642.9ms
# Speed: 6.0ms preprocess, 2642.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2302.4ms
# Speed: 2.8ms preprocess, 2302.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2277.1ms
# Speed: 2.6ms preprocess, 2277.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2301.4ms
# Speed: 2.7ms preprocess, 2301.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 200/375 frames (53.3%)
#
# 0: 384x640 1 ball, 14 players, 3140.3ms
# Speed: 2.9ms preprocess, 3140.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2366.0ms
# Speed: 2.8ms preprocess, 2366.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2282.1ms
# Speed: 4.5ms preprocess, 2282.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2305.0ms
# Speed: 2.5ms preprocess, 2305.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 2299.9ms
# Speed: 3.0ms preprocess, 2299.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3268.6ms
# Speed: 3.0ms preprocess, 3268.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2287.7ms
# Speed: 3.1ms preprocess, 2287.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2309.2ms
# Speed: 2.5ms preprocess, 2309.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2307.1ms
# Speed: 2.6ms preprocess, 2307.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2287.0ms
# Speed: 2.5ms preprocess, 2287.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3180.3ms
# Speed: 3.3ms preprocess, 3180.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2288.4ms
# Speed: 2.7ms preprocess, 2288.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2307.6ms
# Speed: 2.7ms preprocess, 2307.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2301.9ms
# Speed: 3.9ms preprocess, 2301.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 10 players, 2491.5ms
# Speed: 2.8ms preprocess, 2491.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 2983.8ms
# Speed: 3.0ms preprocess, 2983.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2290.4ms
# Speed: 3.9ms preprocess, 2290.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2309.0ms
# Speed: 3.0ms preprocess, 2309.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 2277.5ms
# Speed: 2.5ms preprocess, 2277.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2751.8ms
# Speed: 3.0ms preprocess, 2751.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 2786.2ms
# Speed: 3.0ms preprocess, 2786.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 2271.0ms
# Speed: 3.8ms preprocess, 2271.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 2288.6ms
# Speed: 3.3ms preprocess, 2288.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 2294.7ms
# Speed: 3.0ms preprocess, 2294.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 2825.8ms
# Speed: 3.0ms preprocess, 2825.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 2712.6ms
# Speed: 3.4ms preprocess, 2712.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 9 players, 2297.3ms
# Speed: 3.1ms preprocess, 2297.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 2275.9ms
# Speed: 3.0ms preprocess, 2275.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 2291.2ms
# Speed: 2.9ms preprocess, 2291.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 11 players, 2885.3ms
# Speed: 3.0ms preprocess, 2885.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 2630.7ms
# Speed: 3.2ms preprocess, 2630.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2291.0ms
# Speed: 4.7ms preprocess, 2291.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 2299.5ms
# Speed: 3.7ms preprocess, 2299.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 8 players, 2290.9ms
# Speed: 3.4ms preprocess, 2290.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 3049.1ms
# Speed: 3.1ms preprocess, 3049.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2468.4ms
# Speed: 3.2ms preprocess, 2468.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 2297.3ms
# Speed: 2.6ms preprocess, 2297.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 2294.7ms
# Speed: 2.7ms preprocess, 2294.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 2281.4ms
# Speed: 3.1ms preprocess, 2281.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 3188.1ms
# Speed: 3.0ms preprocess, 3188.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 2354.3ms
# Speed: 5.8ms preprocess, 2354.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 2289.1ms
# Speed: 2.8ms preprocess, 2289.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 2316.7ms
# Speed: 3.2ms preprocess, 2316.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2288.3ms
# Speed: 2.8ms preprocess, 2288.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 3277.0ms
# Speed: 3.2ms preprocess, 3277.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 2289.4ms
# Speed: 3.0ms preprocess, 2289.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 2292.4ms
# Speed: 2.8ms preprocess, 2292.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 2313.3ms
# Speed: 2.7ms preprocess, 2313.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 2449.9ms
# Speed: 3.2ms preprocess, 2449.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 3357.7ms
# Speed: 3.5ms preprocess, 3357.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 2282.5ms
# Speed: 2.6ms preprocess, 2282.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 2279.9ms
# Speed: 3.5ms preprocess, 2279.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 2306.2ms
# Speed: 3.0ms preprocess, 2306.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 2307.5ms
# Speed: 2.8ms preprocess, 2307.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 3283.9ms
# Speed: 2.8ms preprocess, 3283.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2283.2ms
# Speed: 2.5ms preprocess, 2283.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2295.8ms
# Speed: 2.9ms preprocess, 2295.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 2289.7ms
# Speed: 3.8ms preprocess, 2289.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 2286.8ms
# Speed: 3.1ms preprocess, 2286.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3257.8ms
# Speed: 3.0ms preprocess, 3257.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2298.4ms
# Speed: 2.7ms preprocess, 2298.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 2300.8ms
# Speed: 3.7ms preprocess, 2300.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2290.6ms
# Speed: 3.0ms preprocess, 2290.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2332.6ms
# Speed: 3.1ms preprocess, 2332.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 3183.5ms
# Speed: 4.9ms preprocess, 3183.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2314.9ms
# Speed: 2.9ms preprocess, 2314.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2281.6ms
# Speed: 2.8ms preprocess, 2281.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2299.4ms
# Speed: 3.1ms preprocess, 2299.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2392.0ms
# Speed: 2.9ms preprocess, 2392.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3133.9ms
# Speed: 3.1ms preprocess, 3133.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 2301.2ms
# Speed: 2.6ms preprocess, 2301.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2299.9ms
# Speed: 3.3ms preprocess, 2299.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 2305.2ms
# Speed: 3.3ms preprocess, 2305.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 2524.6ms
# Speed: 2.9ms preprocess, 2524.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 2971.2ms
# Speed: 3.7ms preprocess, 2971.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 2282.0ms
# Speed: 2.7ms preprocess, 2282.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 2302.1ms
# Speed: 3.0ms preprocess, 2302.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 2306.2ms
# Speed: 2.9ms preprocess, 2306.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 2650.1ms
# Speed: 2.9ms preprocess, 2650.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2835.5ms
# Speed: 3.1ms preprocess, 2835.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2291.7ms
# Speed: 3.1ms preprocess, 2291.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2286.4ms
# Speed: 3.0ms preprocess, 2286.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2300.9ms
# Speed: 2.9ms preprocess, 2300.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2827.1ms
# Speed: 2.5ms preprocess, 2827.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2664.1ms
# Speed: 3.8ms preprocess, 2664.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2288.5ms
# Speed: 2.8ms preprocess, 2288.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2282.2ms
# Speed: 2.6ms preprocess, 2282.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2279.5ms
# Speed: 2.8ms preprocess, 2279.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 2963.7ms
# Speed: 4.3ms preprocess, 2963.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2506.6ms
# Speed: 3.4ms preprocess, 2506.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 2288.2ms
# Speed: 2.9ms preprocess, 2288.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2281.5ms
# Speed: 2.9ms preprocess, 2281.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2276.3ms
# Speed: 3.2ms preprocess, 2276.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3115.4ms
# Speed: 2.5ms preprocess, 3115.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2393.5ms
# Speed: 4.6ms preprocess, 2393.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2279.0ms
# Speed: 3.0ms preprocess, 2279.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2286.7ms
# Speed: 2.8ms preprocess, 2286.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 2277.2ms
# Speed: 2.9ms preprocess, 2277.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 3293.8ms
# Speed: 3.2ms preprocess, 3293.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2310.5ms
# Speed: 3.7ms preprocess, 2310.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 300/375 frames (80.0%)
#
# 0: 384x640 1 goalkeeper, 15 players, 2294.1ms
# Speed: 3.1ms preprocess, 2294.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 2271.9ms
# Speed: 5.4ms preprocess, 2271.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 2288.5ms
# Speed: 3.0ms preprocess, 2288.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 3261.1ms
# Speed: 2.8ms preprocess, 3261.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 2280.3ms
# Speed: 3.1ms preprocess, 2280.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2289.3ms
# Speed: 3.0ms preprocess, 2289.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2280.6ms
# Speed: 3.0ms preprocess, 2280.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 2323.3ms
# Speed: 2.9ms preprocess, 2323.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3124.8ms
# Speed: 4.7ms preprocess, 3124.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 2295.0ms
# Speed: 4.5ms preprocess, 2295.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2294.8ms
# Speed: 2.5ms preprocess, 2294.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2288.4ms
# Speed: 2.9ms preprocess, 2288.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 2631.2ms
# Speed: 3.8ms preprocess, 2631.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 2873.1ms
# Speed: 3.9ms preprocess, 2873.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 2285.7ms
# Speed: 3.9ms preprocess, 2285.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 2299.8ms
# Speed: 2.9ms preprocess, 2299.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2301.5ms
# Speed: 3.4ms preprocess, 2301.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 2904.0ms
# Speed: 4.4ms preprocess, 2904.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 16 players, 2622.3ms
# Speed: 6.3ms preprocess, 2622.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 2299.5ms
# Speed: 4.3ms preprocess, 2299.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2277.6ms
# Speed: 3.1ms preprocess, 2277.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2288.8ms
# Speed: 2.9ms preprocess, 2288.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 3032.9ms
# Speed: 2.9ms preprocess, 3032.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2476.4ms
# Speed: 3.0ms preprocess, 2476.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2277.8ms
# Speed: 2.9ms preprocess, 2277.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2280.4ms
# Speed: 2.6ms preprocess, 2280.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2297.5ms
# Speed: 2.8ms preprocess, 2297.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 3235.8ms
# Speed: 2.9ms preprocess, 3235.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 2305.1ms
# Speed: 2.8ms preprocess, 2305.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2282.9ms
# Speed: 2.8ms preprocess, 2282.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2301.4ms
# Speed: 2.9ms preprocess, 2301.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2283.2ms
# Speed: 2.9ms preprocess, 2283.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3262.4ms
# Speed: 2.6ms preprocess, 3262.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2279.4ms
# Speed: 3.0ms preprocess, 2279.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2297.0ms
# Speed: 3.3ms preprocess, 2297.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 2296.8ms
# Speed: 2.9ms preprocess, 2296.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 2281.2ms
# Speed: 2.8ms preprocess, 2281.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3259.6ms
# Speed: 2.7ms preprocess, 3259.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 2309.7ms
# Speed: 2.9ms preprocess, 2309.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2312.1ms
# Speed: 4.9ms preprocess, 2312.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2289.3ms
# Speed: 4.2ms preprocess, 2289.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2296.6ms
# Speed: 3.0ms preprocess, 2296.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3251.5ms
# Speed: 3.1ms preprocess, 3251.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2344.4ms
# Speed: 2.5ms preprocess, 2344.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2299.1ms
# Speed: 2.7ms preprocess, 2299.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2302.2ms
# Speed: 3.8ms preprocess, 2302.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2493.2ms
# Speed: 3.1ms preprocess, 2493.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3028.7ms
# Speed: 3.0ms preprocess, 3028.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2296.1ms
# Speed: 3.1ms preprocess, 2296.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2294.8ms
# Speed: 3.1ms preprocess, 2294.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2287.5ms
# Speed: 3.2ms preprocess, 2287.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2714.3ms
# Speed: 3.0ms preprocess, 2714.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2811.0ms
# Speed: 3.0ms preprocess, 2811.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2286.8ms
# Speed: 3.2ms preprocess, 2286.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2295.6ms
# Speed: 2.9ms preprocess, 2295.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2282.9ms
# Speed: 3.1ms preprocess, 2282.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2913.5ms
# Speed: 2.6ms preprocess, 2913.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2576.2ms
# Speed: 3.0ms preprocess, 2576.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2313.7ms
# Speed: 3.1ms preprocess, 2313.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2299.3ms
# Speed: 2.9ms preprocess, 2299.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2278.6ms
# Speed: 3.1ms preprocess, 2278.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 3106.5ms
# Speed: 3.2ms preprocess, 3106.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2382.8ms
# Speed: 4.9ms preprocess, 2382.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2297.2ms
# Speed: 3.3ms preprocess, 2297.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2287.1ms
# Speed: 3.1ms preprocess, 2287.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2287.5ms
# Speed: 3.2ms preprocess, 2287.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3326.7ms
# Speed: 3.2ms preprocess, 3326.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2311.4ms
# Speed: 2.9ms preprocess, 2311.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2306.2ms
# Speed: 2.7ms preprocess, 2306.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2306.8ms
# Speed: 2.8ms preprocess, 2306.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2326.3ms
# Speed: 3.8ms preprocess, 2326.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3274.7ms
# Speed: 2.4ms preprocess, 3274.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 2293.3ms
# Speed: 2.7ms preprocess, 2293.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 2278.4ms
# Speed: 3.4ms preprocess, 2278.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 2323.2ms
# Speed: 3.0ms preprocess, 2323.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Video processing completed. Total unique players tracked: 21
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-3279124218.py in <cell line: 0>()
#     419
#     420 if __name__ == "__main__":
# --> 421     main()
#
# /tmp/ipython-input-6-3279124218.py in main()
#     405     print("Starting player tracking and re-identification...")
#     406     tracking_history = tracker.process_video(INPUT_VIDEO, OUTPUT_VIDEO)
# --> 407     tracker.save_results(OUTPUT_DIR)
#     408     tracker.visualize_tracking_paths(INPUT_VIDEO, os.path.join(OUTPUT_DIR, 'tracking_paths.jpg'))
#     409
#
# /tmp/ipython-input-6-3279124218.py in save_results(self, output_dir)
#     334
#     335         with open(os.path.join(output_dir, 'tracking_summary.json'), 'w') as f:
# --> 336             json.dump(tracking_data, f, indent=2)
#     337
#     338         with open(os.path.join(output_dir, 'player_features.pkl'), 'wb') as f:
#
# /usr/lib/python3.11/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# /usr/lib/python3.11/json/encoder.py in _iterencode(o, _current_indent_level)
#     430             yield from _iterencode_list(o, _current_indent_level)
#     431         elif isinstance(o, dict):
# --> 432             yield from _iterencode_dict(o, _current_indent_level)
#     433         else:
#     434             if markers is not None:
#
# /usr/lib/python3.11/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     404                 else:
#     405                     chunks = _iterencode(value, _current_indent_level)
# --> 406                 yield from chunks
#     407         if newline_indent is not None:
#     408             _current_indent_level -= 1
#
# /usr/lib/python3.11/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     324                 else:
#     325                     chunks = _iterencode(value, _current_indent_level)
# --> 326                 yield from chunks
#     327         if newline_indent is not None:
#     328             _current_indent_level -= 1
#
# /usr/lib/python3.11/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     404                 else:
#     405                     chunks = _iterencode(value, _current_indent_level)
# --> 406                 yield from chunks
#     407         if newline_indent is not None:
#     408             _current_indent_level -= 1
#
# /usr/lib/python3.11/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     324                 else:
#     325                     chunks = _iterencode(value, _current_indent_level)
# --> 326                 yield from chunks
#     327         if newline_indent is not None:
#     328             _current_indent_level -= 1
#
# /usr/lib/python3.11/json/encoder.py in _iterencode(o, _current_indent_level)
#     437                     raise ValueError("Circular reference detected")
#     438                 markers[markerid] = o
# --> 439             o = _default(o)
#     440             yield from _iterencode(o, _current_indent_level)
#     441             if markers is not None:
#
# /usr/lib/python3.11/json/encoder.py in default(self, o)
#     178
#     179         """
# --> 180         raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                         f'is not JSON serializable')
#     182
#
# TypeError: Object of type ndarray is not JSON serializable
